# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url="https://careerhunts.com/job/google/nodal-officer-google-pay-navi-mumbai-20400?"
response=requests.get(url)
html_content=response.text

# %%
response
# Out:
# <Response [200]>

# %%
html_content
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n<meta charset="UTF-8">\n<title>Nodal Officer, Google Pay job in Navi Mumbai by Google for 10 - 13 Years Experience - Careerhunts.com</title>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="description" content="Qualifications\r\n\r\nMinimum qualifications:\r\n\r\n\r\n\tLaw/Accountant/Technical masters certification\r\n\t10 years of rel" />\n<meta name="keywords" content="Nodal Officer, Google Pay, Full Time job in Navi Mumbai, Administration, Law enforcement, Compliance, Analytical, Finance, Process improvement, Legal, Management, Recruitment, IT-Software/Software Services, IT Software" />\n<meta name="google-site-verification" content="FhczD0l-cOS5WJN_5BAIU_YdZuczSGX5FrsOBtB8ov4" />\n<meta property="og:locale" content="en_IN">\n<meta property="og:type" content="website">\n<meta property="og:title" content="Nodal Officer, Google Pay job in Navi Mumbai by Google for 10 - 13 Years Experience - Careerhunts.
# ...

# %%
soup=BeautifulSoup(html_content,'html.parser')
a=soup.find_all('script', {'type':'application/ld+json'},recursive=True)

# %%
a
# Out:
# [<script type="application/ld+json">
#  {
#    "@context": "https://schema.org",
#    "@type": "Organization",
#    "name": "Career Hunts",
#    "alternateName": "CareerHunts",
#    "url": "https://www.careerhunts.com/",
#    "logo": "https://www.careerhunts.com/public/seeker-assets/images/careerhunts-logo.png",
#    "sameAs": [
#      "https://www.facebook.com/Careerhunts/",
#      "https://twitter.com/HuntsCareer",
#      "https://www.instagram.com/careerhuntskolkata/",
#      "https://www.youtube.com/channel/UCNSuJ3KndGAgGMZnJOGdjNw",
#      "https://www.linkedin.com/company/career-hunts",
#      "https://in.pinterest.com/career_hunts"
#    ]
#  }
#  </script>,
#  <script type="application/ld+json">
#  {
#    "@context": "https://schema.org/",
#    "@type": "BreadcrumbList",
#    "itemListElement": [{
#      "@type": "ListItem",
#      "position": 1,
#      "name": "home",
#      "item": "https://www.careerhunts.com/"
#    },{
#  					"@type": "ListItem",
#  					"position": 2,
# ...

# %%
data = []
for i in a:
    print("i::  ",i)
    data.append(json.loads(i.string,strict=False))
# Out:
# i::   <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "name": "Career Hunts",
#   "alternateName": "CareerHunts",
#   "url": "https://www.careerhunts.com/",
#   "logo": "https://www.careerhunts.com/public/seeker-assets/images/careerhunts-logo.png",
#   "sameAs": [
#     "https://www.facebook.com/Careerhunts/",
#     "https://twitter.com/HuntsCareer",
#     "https://www.instagram.com/careerhuntskolkata/",
#     "https://www.youtube.com/channel/UCNSuJ3KndGAgGMZnJOGdjNw",
#     "https://www.linkedin.com/company/career-hunts",
#     "https://in.pinterest.com/career_hunts"
#   ]
# }
# </script>
# i::   <script type="application/ld+json">
# {
#   "@context": "https://schema.org/",
#   "@type": "BreadcrumbList",
#   "itemListElement": [{
#     "@type": "ListItem",
#     "position": 1,
#     "name": "home",
#     "item": "https://www.careerhunts.com/"
#   },{
# 					"@type": "ListItem",
# 					"position": 2,
# ...

# %%
data[0]
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'Organization',
#  'name': 'Career Hunts',
#  'alternateName': 'CareerHunts',
#  'url': 'https://www.careerhunts.com/',
#  'logo': 'https://www.careerhunts.com/public/seeker-assets/images/careerhunts-logo.png',
#  'sameAs': ['https://www.facebook.com/Careerhunts/',
#   'https://twitter.com/HuntsCareer',
#   'https://www.instagram.com/careerhuntskolkata/',
#   'https://www.youtube.com/channel/UCNSuJ3KndGAgGMZnJOGdjNw',
#   'https://www.linkedin.com/company/career-hunts',
#   'https://in.pinterest.com/career_hunts']}
